# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import numpy as np
from nuflux.detgeo import SimulateDetector
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
sim = SimulateDetector(param = 'mutristan s', N_evals = 1e5)
# Out:
# Succesfully simulated decays:
# μTRISTAN (s) parameter set with 1.000e+05 evaluations
# 1.875e+05 MC generations; took 3.64 s

# %%
sim.run(Lss = 0, collision = 'mu+mu+', show_time = 0, show_components = 0)
# Out:
# Successfully simulated neutrino event rates within Det v2:
# μTRISTAN (s) (μ+μ+) at L = 0.00 m.
# Total count: 2.69e+11 events; took 14.9 s (numba pre-compilation needed).

# %%
sim.plot(sec = 'muon_detector_barrel')

# %%
sim.event_timing(sec = 'muon_detector_barrel')

# %%
help(sim)
# Out:
# Help on SimulateDetector in module nuflux.detgeo object:
#
# class SimulateDetector(builtins.object)
#  |  SimulateDetector(param='mutristan s', N_evals=100000.0, alr_loaded=False, dt=None)
#  |
#  |  Simulating the whole detector interactions.
#  |  Hierarchy is as follows: Initializing SimulateDetector calls SimulateDecays; running simulates many SimNeutrinos based on the collision type, which is a single-neutrino-species MC generation of events within a detector.
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, param='mutristan s', N_evals=100000.0, alr_loaded=False, dt=None)
#  |      Initializes from muon decay sim.
#  |
#  |  energies(self, fs=(20, 12), histtype='step', nbins=100, savefig=None, label='', legend=False, linestyle='-', sec='all')
#  |      Wrapper to plot energy flux of particles.
#  |
#  |      Args:
#  |          savefig (str): name of file to save plot to.
#  |          histtype (str): plt histtype options.
# ...
