# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import numpy as np
from nuflux.detgeo import SimulateDetector, check_mem

# %%
sim = SimulateDetector(param = 'mutristan s', N_evals = 1e5)
# Out:
# Succesfully simulated decays:
# μTRISTAN (s) parameter set with 1.000e+05 evaluations .
# 1.876e+05 MC generations; took 6.92 s.

# %%
sim.run(Lss = 0, collision = 'mu+mu+', show_time = 0, show_components = 0)
# Out:
# Successfully simulated neutrino event rates within Det v2:
# μTRISTAN (s) (μ+μ+) at L = 0.00 m.
# Total count: 2.73e+11 events; took 3.29 s (numba pre-compilation needed).

# %%
sim.plot(sec = 'muon_detector_ec')

# %%
#sim.event_timing(sec = 'muon_detector_barrel')

# %%
#help(sim)

# %%
check_mem()
# Out:
# Filename: /home/luc/Research/BIN_MC/nuflux/detgeo.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# ...
#     33    231.7 MiB    231.7 MiB           1   @profile
#     34                                         def check_mem():
#     35                                             '''For memory-consuming-checking processes.'''
#     36    231.7 MiB      0.0 MiB           1       z = 1+2
#     37    231.7 MiB      0.0 MiB           1       return

# %%
vars(sim.sims[0])
# Out:
# {'time': array([1.72188258e+09, 1.72188258e+09, 1.72188258e+09, 1.72188259e+09,
#         1.72188259e+09, 1.72188259e+09]),
#  'd': 'left',
#  'rmax': 645.0,
#  'zending': 563.8,
#  'face_dict': {'muon_detector_ec': [1, 31, 8, 49, 93],
#   'muon_detector_barrel': [26, 88],
#   'solenoid': [20, 21, 22, 23, 24, 25, 32, 33, 34],
#   'hcal_ec': [10, 19, 28, 39, 47, 72, 76, 77, 81],
#   'hcal_barrel': [29, 30, 71],
#   'ecal_ec': [11, 35, 42, 46, 52, 68, 83, 86],
#   'ecal_barrel': [41, 69, 70],
#   'nozzles': [-2, 2, 14, 15, 17, 27, 43, 78, 53, 66, 67, 82, 85, 87]},
#  'detname': 'Det v2',
#  'particle': 'nue',
#  'mutimes': array([1.87619012e-07, 1.87619012e-07, 1.87619012e-07, ...,
#         1.31806204e-07, 1.31806204e-07, 1.31806204e-07]),
#  'paramname': 'μTRISTAN (s)',
#  'Lval': 0,
#  'E': array([ 41.31330032,  41.31330032,  41.31330032, ..., 483.25489999,
#         483.25489999, 483.25489999]),
#  'location': array([ 1, 19, 29, ..., 71, 72, 31]),
# ...
